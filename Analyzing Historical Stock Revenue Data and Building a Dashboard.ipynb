# %% [markdown]
# # Peer-graded Assignment: Analyzing Historical Stock/Revenue Data and Building a Dashboard
#
# ### Full Points: Working code that yields correct results
#
# You will be graded on the dashboards displaying the specified data and the screenshots you took during the final project lab questions. There are 12 possible points for this assignment. Here is the breakdown:
#
# - **Question 1** - Extracting Tesla Stock Data Using `yfinance` - **2 Points**
# - **Question 2** - Extracting Tesla Revenue Data Using Webscraping - **1 Point**
# - **Question 3** - Extracting GameStop Stock Data Using `yfinance` - **2 Points**
# - **Question 4** - Extracting GameStop Revenue Data Using Webscraping - **1 Point**
# - **Question 5** - Tesla Stock and Revenue Dashboard - **2 Points**
# - **Question 6** - GameStop Stock and Revenue Dashboard - **2 Points**
# - **Question 7** - Sharing your Assignment Notebook - **2 Points**
#
# For each problem, points will be awarded as follows:
#
# - **Full Points:** Working code that yields correct results
# - **Partial Points:** Partially correct code or results
# - **No Points:** Did not attempt the problem or did not upload any solution

# %%
# !pip install yfinance
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install html5lib
# !pip install lxml
# !pip install plotly
# Out:
# ...
#   Using cached lxml-5.3.0-cp39-cp39-win_amd64.whl (3.8 MB)
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.6.4
#     Uninstalling lxml-4.6.4:
#       Successfully uninstalled lxml-4.6.4
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\johny\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\johny\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\johny\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\johny\anaconda3\lib\http\client.py", line 462, in read
#     n = self.readinto(b)
#   File "C:\Users\johny\anaconda3\lib\http\client.py", line 506, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\johny\anaconda3\lib\socket.py", line 704, in readinto
# ...

# %% [markdown]
# # Question 1 - Extracting Tesla Stock Data Using yfinance

# %%
import yfinance as yf

# Define the ticker symbol for Tesla
ticker_symbol = "TSLA"

# Get data on this ticker
tesla_data = yf.Ticker(ticker_symbol)

# Get the historical market data
tesla_stock_data = tesla_data.history(period="max")

# Display the first few rows of the data
tesla_stock_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %% [markdown]
# # Question 2 - Extracting Tesla Revenue Data Using Webscraping - 1 Point

# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests

# URL of the webpage to download
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"

# Send a GET request to the webpage
response = requests.get(url)

# Save the text of the response as a variable
html_data = response.text

# Print the first 500 characters to verify
print(html_data[:500])
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 		<link rel="canonical" href="https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue" />

# %%
from bs4 import BeautifulSoup

# Assuming you have `html_data` from the previous steps:
# If you used `response.text`, you should convert it to bytes for `.content` usage.
html_data_content = html_data.encode('utf-8')

# Parse the HTML data using BeautifulSoup with the html5lib parser
soup = BeautifulSoup(html_data_content, 'html5lib')

# Alternatively, you can use the built-in html.parser:
# soup = BeautifulSoup(html_data_content, 'html.parser')

# Optionally, print the first few elements to verify
print(soup.prettify()[:500])
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue" rel="canonical"/>
#   <title>
#    Te

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Download the webpage content
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
response = requests.get(url)
html_data = response.content

# Parse the HTML data using BeautifulSoup with html.parser
soup = BeautifulSoup(html_data, 'html.parser')

# Find all tables in the webpage
tables = soup.find_all('table')

# Initialize an empty DataFrame
tesla_revenue = pd.DataFrame(columns=["Date", "Revenue"])

# Loop through each table to find the relevant one
for table in tables:
    if "Tesla Quarterly Revenue" in table.text:
        # Loop through the rows of the table (excluding the header)
        for row in table.find_all("tr")[1:]:
            cols = row.find_all("td")
            date = cols[0].text.strip()
            revenue = cols[1].text.strip()
            
            # Add the data to the DataFrame
            tesla_revenue = pd.concat([tesla_revenue, pd.DataFrame([[date, revenue]], columns=["Date", "Revenue"])], ignore_index=True)

# Remove commas and dollar signs from the Revenue column
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$', "", regex=True)

tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]

# Display the last 5 rows of the tesla_revenue DataFrame
print(tesla_revenue.tail())
# Out:
#           Date Revenue
# 48  2010-09-30      31
# 49  2010-06-30      28
# 50  2010-03-31      21
# 52  2009-09-30      46
# 53  2009-06-30      27

# %% [markdown]
# # Question 3 - Extracting GameStop Stock Data Using yfinance - 2 Points

# %%
import yfinance as yf

# Define the ticker symbol for GameStop
ticker_symbol = "GME"

# Get data on this ticker
gamestop_data = yf.Ticker(ticker_symbol)

# Get the historical market data
gamestop_stock_data = gamestop_data.history(period="max")

# Display the first few rows of the data
gamestop_stock_data.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620129  1.693350  1.603296  1.691667  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716074  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658002  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %% [markdown]
# # Question 4 - Extracting GameStop Revenue Data Using Webscraping - 1 Point

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Download the webpage content
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"
response = requests.get(url)
html_data = response.content

# Parse the HTML data using BeautifulSoup with html.parser
soup = BeautifulSoup(html_data, 'html.parser')

# Find all tables in the webpage
tables = soup.find_all('table')

# Initialize an empty DataFrame
gme_data = pd.DataFrame(columns=["Date", "Revenue"])

# Loop through each table to find the relevant one
for table in tables:
    if "GameStop Quarterly Revenue" in table.text:
        # Loop through the rows of the table (excluding the header)
        for row in table.find_all("tr")[1:]:
            cols = row.find_all("td")
            date = cols[0].text.strip()
            revenue = cols[1].text.strip()
            
            # Add the data to the DataFrame
            gme_data = pd.concat([gme_data, pd.DataFrame([[date, revenue]], columns=["Date", "Revenue"])], ignore_index=True)

# Remove commas and dollar signs from the Revenue column
gme_data["Revenue"] = gme_data['Revenue'].str.replace(',|\$', "", regex=True)

# Display the last 5 rows of the gme_data DataFrame
print(gme_data.tail())
# Out:
#           Date Revenue
# 57  2006-01-31    1667
# 58  2005-10-31     534
# 59  2005-07-31     416
# 60  2005-04-30     475
# 61  2005-01-31     709

# %% [markdown]
# # Question 5 - Tesla Stock and Revenue Dashboard - 2 Points

# %%
# !pip install yfinance plotly

# %%
import yfinance as yf
import plotly.graph_objs as go

# Load Tesla stock data
ticker_symbol = "TSLA"
tesla_data = yf.Ticker(ticker_symbol)
tesla_stock_data = tesla_data.history(period="max")

# Filter the data up to June 2021
tesla_stock_data_filtered = tesla_stock_data[tesla_stock_data.index <= "2021-06-30"]

# %%
def make_graph(stock_data, revenue_data, title):
    fig = go.Figure()

    # Plot the stock price data
    fig.add_trace(go.Scatter(x=stock_data.index, y=stock_data['Close'], mode='lines', name='Stock Price'))

    # Add title and labels
    fig.update_layout(
        title=f"{title} Stock Data",
        xaxis_title="Date",
        yaxis_title="Stock Price (USD)",
        yaxis2=dict(title="Revenue", overlaying="y", side="right"),
        legend=dict(x=0, y=1)
    )

    fig.show()

# %%
#There is no revenue in yahoo finance web.  
make_graph(tesla_stock_data_filtered, None, 'Tesla')
# Out:
# <div>                            <div id="66ee8ce5-3b1b-4412-8ddc-57e95bb69bea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66ee8ce5-3b1b-4412-8ddc-57e95bb69bea")) {                    Plotly.newPlot(                        "66ee8ce5-3b1b-4412-8ddc-57e95bb69bea",                        [{"mode":"lines","name":"Stock Price","x":["2010-06-29T00:00:00-04:00","2010-06-30T00:00:00-04:00","2010-07-01T00:00:00-04:00","2010-07-02T00:00:00-04:00","2010-07-06T00:00:00-04:00","2010-07-07T00:00:00-04:00","2010-07-08T00:00:00-04:00","2010-07-09T00:00:00-04:00","2010-07-12T00:00:00-04:00","2010-07-13T00:00:00-04:00","2010-07-14T00:00:00-04:00","2010-07-15T00:00:00-04:00","2010-07-16T00:00:00-04:00","2010-07-19T00:00:00-04:00","2010-07-20T00:00:00-04:00","2010
# ...

# %% [markdown]
# # Question 6 - GameStop Stock and Revenue Dashboard - 2 Points

# %%
import yfinance as yf
import plotly.graph_objs as go

# Load Tesla stock data
ticker_symbol = "GME"
tesla_data = yf.Ticker(ticker_symbol)
tesla_stock_data = tesla_data.history(period="max")

# Filter the data up to June 2021
tesla_stock_data_filtered = tesla_stock_data[tesla_stock_data.index <= "2021-06-30"]

# %%
def make_graph(stock_data, revenue_data, title):
    fig = go.Figure()

    # Plot the stock price data
    fig.add_trace(go.Scatter(x=stock_data.index, y=stock_data['Close'], mode='lines', name='Stock Price'))

    # Add title and labels
    fig.update_layout(
        title=f"{title} Stock Data",
        xaxis_title="Date",
        yaxis_title="Stock Price (USD)",
        yaxis2=dict(title="Revenue", overlaying="y", side="right"),
        legend=dict(x=0, y=1)
    )

    fig.show()

# %%
#There is no revenue in yahoo finance web.  
make_graph(tesla_stock_data_filtered, None, 'Game Stop')
# Out:
# <div>                            <div id="dadeb032-ef4a-4b0d-8fec-e3a3a21fe4ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dadeb032-ef4a-4b0d-8fec-e3a3a21fe4ea")) {                    Plotly.newPlot(                        "dadeb032-ef4a-4b0d-8fec-e3a3a21fe4ea",                        [{"mode":"lines","name":"Stock Price","x":["2002-02-13T00:00:00-05:00","2002-02-14T00:00:00-05:00","2002-02-15T00:00:00-05:00","2002-02-19T00:00:00-05:00","2002-02-20T00:00:00-05:00","2002-02-21T00:00:00-05:00","2002-02-22T00:00:00-05:00","2002-02-25T00:00:00-05:00","2002-02-26T00:00:00-05:00","2002-02-27T00:00:00-05:00","2002-02-28T00:00:00-05:00","2002-03-01T00:00:00-05:00","2002-03-04T00:00:00-05:00","2002-03-05T00:00:00-05:00","2002-03-06T00:00:00-05:00","2002
# ...

# %% [markdown]
# # Question 7 - Sharing your Assignment Notebook - 2 Points

# %% [markdown]
# # Shared
